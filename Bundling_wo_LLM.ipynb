# %%
import re

def extract_variables_section(text):
    
    variables_section_pattern = r"\*\*\* Variables \*\*\*(.*?)(?=\n\*\*\*|\Z)"
    match = re.search(variables_section_pattern, text, re.DOTALL)
    if match:
        return match.group(1).strip()
    return ""


def extract_resources(text) :
    content = rfc

    settings_section_pattern = r"\*\*\* Settings \*\*\*(.*?)(?=\n\*\*\*|\Z)"
    library_pattern = r"Library\s+(.+)"
    resource_pattern = r"Resource\s+(.+)"
    variables_pattern = r"Variables\s+(.+)"
    settings_section_match = re.search(settings_section_pattern, content, re.DOTALL)
    if settings_section_match:
        settings_section = settings_section_match.group(1)
        libraries = re.findall(library_pattern, settings_section)
        resources = re.findall(resource_pattern, settings_section)
        variables = re.findall(variables_pattern, settings_section)
        return (libraries , resources , variables)
    else:
        print("No *** Settings *** section found.")
        return ([],[],[])
    
def extract_keywords_section(text):
    keywords_section_pattern = r"\*\*\* Keywords \*\*\*(.*?)(?=\n\*\*\*|\Z)"
    match = re.search(keywords_section_pattern, text, re.DOTALL)
    if match:
        return match.group(1).strip()
    return ""

def extract_sttl_content_and_suite_sections(text, sttl_ids_to_filter):
    sttl_pattern = r"(STTL-\d+)(.*?)(?=\nSTTL-\d+|\n\*|\Z)"
    matches = re.findall(sttl_pattern, text, re.DOTALL)
    test_cases = {}
    for match in matches:
        sttl_id, content = match
        if sttl_id in sttl_ids_to_filter:
            test_cases[sttl_id] = f"{sttl_id}{content}".strip()
    

    suite_setup_pattern = r"\*\*\* Settings \*\*\*.*?Suite Setup\s+(.*?)(?=\n\w|\Z)"
    suite_teardown_pattern = r"\*\*\* Settings \*\*\*.*?Suite Teardown\s+(.*?)(?=\n\w|\Z)"
    test_setup_pattern = r"\*\*\* Settings \*\*\*.*?Test Setup\s+(.*?)(?=\n\w|\Z)"
    test_teardown_pattern = r"\*\*\* Settings \*\*\*.*?Test Teardown\s+(.*?)(?=\n\w|\Z)"
    test_timeout_pattern = r"\*\*\* Settings \*\*\*.*?Test Timeout\s+(.*?)(?=\r?\n|$)" 
    
    suite_setup_match = re.search(suite_setup_pattern, text, re.DOTALL)
    suite_teardown_match = re.search(suite_teardown_pattern, text, re.DOTALL)
    test_setup_match = re.search(test_setup_pattern, text, re.DOTALL)
    test_teardown_match = re.search(test_teardown_pattern, text, re.DOTALL)
    test_timeout_match = re.search(test_timeout_pattern, text, re.DOTALL)


    suite_setup = suite_setup_match.group(1).strip() if suite_setup_match else "Not found"
    suite_teardown = suite_teardown_match.group(1).strip() if suite_teardown_match else "Not found"
    test_setup = test_setup_match.group(1).strip() if test_setup_match else "Not found"
    test_teardown = test_teardown_match.group(1).strip() if test_teardown_match else "Not found"
    test_timeout = test_timeout_match.group(1).strip() if test_timeout_match else "Not found"


    result = {
        'Suite_Setup': suite_setup,
        'Suite_Teardown': suite_teardown,
        'Test_Setup': test_setup,
        'Test_Teardown': test_teardown,
        'Test_Timeout': test_timeout,
        'Test_Cases': test_cases 
    }
    return result

file = f"C:/RFS_CI/GIT_REPO/ST_Master/mcd_validation_RFS/RFS/TS/ANDROID/Android_OSUpdate/OS_Update3.0_Test.robot"

with open(file, "r") as rf:
    rfc = rf.read()

sttl_ids_to_filter = ["STTL-232540", "STTL-230890", "STTL-230895", "STTL-230899", "STTL-230907","STTL-244060","STTL-230904","STTL-231747"] 
extracted_content = extract_sttl_content_and_suite_sections(rfc, sttl_ids_to_filter)
extracted_content['Libraries'] = extract_resources(rfc)[0]
extracted_content['Resources'] = extract_resources(rfc)[1]
extracted_content['Variables'] = extract_resources(rfc)[2]
extracted_content['Keywords'] = extract_keywords_section(rfc)
extracted_content['Variables'] = extract_variables_section(rfc)

# %%
for key,value in extracted_content.items():
    print("-------------------------" , key , "-------------------------")
    print(value)
# Out:
# ------------------------- Suite_Setup -------------------------
# Suite_Setup_OSUpdate
# ------------------------- Suite_Teardown -------------------------
# run keywords
# ...  Perform Factory Reset
# ...  AND  Enable Setup for Automation  ${DUT1}
# ------------------------- Test_Setup -------------------------
# run keywords
# ...  Battery Setup For Staging
# ...  AND  Install  ${EXTERNALFILES_DIRECTORY}\\Android\\APK\\StageNow\\Generic\\BarcodeStaging.apk
# ...  AND  BuiltIn.Sleep  10
# ------------------------- Test_Teardown -------------------------
# run keywords
# ...  Set Serial Number Of Device For All Libraries  ${DUT1}
# ...  AND  run keyword and ignore error  Unlock The Device Screen For All Security Locks
# ...  AND  run keyword and ignore error  Remove The Screen Lock Through Intent
# ------------------------- Test_Timeout -------------------------
# 400 minutes
# ------------------------- Test_Cases -------------------------
# {'STTL-232540': "STTL-232540 - Pre Build Package --UPL- StageNow- Special packages + A11 Factory Reset package -internal location\n    [Tags]  NON-CLM  CC610 (A11)  CC605 (A11)  ET51 (A11)  ET56 (A11)  EC50 (A11)  EC55 (A11)  L10A (A11)  MC22 (A11)  MC27 (A11)  MC33x (A11)  MC93 (A11)\n    ...  TC21 (A11)  TC26 (A11)  TC52 (A11)  TC52X (A11)  TC57 (A11)  TC57X (A11)  TC72 (A11)  TC77 (A11)  TC83 (A11)  TC53 (A11)  TC58 (A11)  WS50 (A11)\n    ${PLAT_FORM}  Get The Device Platform Name\n    Push File To Device  ${EXTERNALFILES_DIRECTORY}//${${PLAT_FORM}_Spl_Factory_Reset_Upl}  /sdcard\n    Push File To Device  ${EXTERNALFILES_DIRECTORY}//${${PLAT_FORM}_Automation_Enable_Pkg}  /sdcard\n    Initiate Stagging and Scan the Barcode  STTL_232540_${PLAT_FORM}.txt\n    ${is_rebooted} =  Check Boot Completed on DUT  600\n    run keyword unless  ${is_rebooted}  FAIL  DUT failed to Boot up after 600 seconds\n    Enable Setup For Automation  ${DUT1}\n    Disable Device Screen Auto-Rotation\n    ${status}  Execute ADB Shell Command On The Device  getprop ro.vendor.symbol.test.automation\n    Should Contain  ${status}  1\n    Create Test Bed PSK Profile And Install WLAN Apps\n    ${Test}  General_ADB_Res.Get Device WLAN Details\n    BuiltIn.Sleep  2s\n    Verify Ping From Host to Device  ${Test}[Device IP Address]\n    Browse Site  www.google.com\n    Scan Common Barcodes after Upgrade  STTL-232540  ${BC_DATA}\n    Delete Existing Albums in Gallery\n    Camera_UIAutomator_Res.Open Camera\n    run keyword if  '${DUT_NAME}' not in ['TC21', 'TC26', 'TC52X', 'TC57X', 'MC2200' 'MC2700', 'EC50', 'EC55', 'MC20', 'RZ_H270']  run keyword  set image capture mode\n    camera capture image  10\n    verify photo/video captured  10\n    Launch app  Calculator\n    Verify Device Screen Orientation for deviceimaging\n    FOR  ${index}  IN RANGE  0  5\n          AndroidGeneralUIAutomator.Reboot Device\n          Verify UUT in Homescreen\n    END\n    [Teardown]  run keywords\n    ...  run keyword if  '${DUT_NAME}' in ['EC30', 'VC8300', 'WT6300']  Set Screen Orientation  natural\n    ...  AND  run keyword if  '${DUT_NAME}' not in ['EC30', 'VC8300', 'WT6300']  Disable Device Screen Auto-Rotation\n    ...  AND  run keyword and ignore error  close imageview", 'STTL-230907': 'STTL-230907 - Negative Test-AB streaming StageNOw-Osupdate3.0-Full OTA -Delta1-Suspend Resume\n    [Tags]  NON-CLM  TC53 (A11)  TC58 (A11)  TC15 (A11)  WS50 (A11)  TN28 (A11)\n    [Setup]  Test Build Pre_Condition SetUp  ${SA_A${DUT_OS}_BASELINE_LOCATION}  ${FULL_PACKAGE_UPDATE}  ${internal_path}  ${DUT1}\n    Create Test Bed PSK Profile And Install WLAN Apps\n    Upgrade OS Build With Full OTA Via AB Streaming  ${ABS_HTTP_NA_DELTA1}  ${DUT1}  ${SA_DELTA_1_A${DUT_OS}_LOCATION}  ${DELTA1_PACKAGE_NAME}\n    Suspend And Resume The Device\n    Functionality Test After Device Upgrade/Downgrade  STTL-230913  ${BC_DATA}', 'STTL-230899': 'STTL-230899 - Pre build -AB streaming Wifi -User Name and Password- Delta2 to FullOta of Delta 1-StaeNow-XML Barcode-downgrade\n    [Tags]  NON-CLM  TC53 (A11)  TC58 (A11)  TC15 (A11)  WS50 (A11)  TN28 (A11)\n    [Setup]  run keywords  Test Build Pre_Condition SetUp  ${SA_A${DUT_OS}_BASELINE_LOCATION}  ${FULL_PACKAGE_UPDATE}  ${internal_path}  ${DUT1}\n    ...  AND  Upgrade OS Build With Diff OTA  ${SA_DELTA_1_A${DUT_OS}_LOCATION}  ${internal_path}  ${REVA_UPDATE}  ${DUT1}  ${DELTA1_PACKAGE_NAME}\n\t...  AND  Upgrade OS Build With Diff OTA  ${SA_DELTA_2_A${DUT_OS}_LOCATION}  ${internal_path}  ${REVA_UPDATE}  ${DUT1}  ${DELTA2_PACKAGE_NAME}\n    Create Test Bed PSK Profile And Install WLAN Apps\n#"Upgrade OS Build With Full OTA Via AB Streaming":This kw works fine for both upgrade and downgrade ,here upgrade/Downgrade depends on in the text file generated via stagenow\n\tUpgrade OS Build With Full OTA Via AB Streaming  ${ABS_HTTP_NEXT_BA_DOWNGRADE}  ${DUT1}  ${SA_A13_NEXT_BASELINE_LOCATION}  ${FULL_PACKAGE_UPDATE}\n    Match all Version with RCR Form\n    Functionali ...
# ------------------------- Libraries -------------------------
# ['Collections', 'ImageRecognitionLibrary']
# ------------------------- Resources -------------------------
# ['${EXECDIR}/Res/Android/AndroidGMS/AndroidGMS_Res.robot', '${EXECDIR}/Res/Android/System/System_UIAutomator_Res.robot', '${EXECDIR}/Res/Android/EMMTK/EMMTK_Keywords.robot', '${EXECDIR}/Res/Android/DeviceImaging/DeviceImaging_UIAutomator_Res.robot', '${EXECDIR}/Res/Common/NetworkTraffic/Ping_Res.robot', '${EXECDIR}/Res/Android/Memory/AndroidMemory_UIAutomator_Res.robot', '${EXECDIR}/Res/Android/RCR_Form/Parse_RCR_Form_Res.robot', '${EXECDIR}/Res/Android/OOB/OOB_Settings_Res.robot', '${EXECDIR}/Res/Android/Browser/Browser_UIAutomator_Res.robot', '${EXECDIR}/Res/Android/EmdkScanner/Scanner_Injection_Common_Res.robot', '${EXECDIR}/Res/Android/AndroidGMSLite/AndroidGMSLite_UIAutomator_Res.robot', '${EXECDIR}/Res/Android/Android_Scan_Stress/Android_Scan_Stress_Res.robot', '${EXECDIR}/Res/Android/Android/AEF/AEF_UIAutomator_Res.robot']
# ------------------------- Variables -------------------------
# &{TOUCH_VIBRATION}  text=Haptic feedback for tap, keyboard, and more
# &{NOTIFICATION_SOUND}  text=Default notification sound
# &{DARK_THEME_LOCATOR}  text=Dark theme
#
# ${TESTSUITE_EXEC_TIMEOUT}  3000
# ${DI_EXEC_ENV}  NON-CLM
# ${A11_Previous_Build}  A10
# ${A13_Previous_Build}  A11
# ------------------------- Keywords -------------------------
# Suite_Setup_OSUpdate
#     [Documentation]  Get the device info
#     Set Serial Number Of Device For All Libraries  ${DUT1}
#     Universal Suite Setup  ${DUT1}
#     ${status}=  Get SDK Friendly Name Of Device
#     set global variable  ${OS_FLAVOUR}  ${status}
#     ${command}  set variable  shell getprop ro.config.bsp.gms
#     ${gms_status}=  execute adb command  ${command}
#     set global variable  ${dev_Gms_status}  ${gms_status[0]}
#     run keyword if  '${dev_Gms_status.strip()}' == 'true'  set global variable  ${build_status}  GMS
#     ...  ELSE  set global variable  ${build_status}  NGMS
#     ${platform}=  Get The Device Platform Name
#     ${command}  set variable  -s ${DUT1} shell getprop ro.config.device.china
#     @{Status}  execute adb command  ${command}
#     set global variable  ${Sku_Status}  ${Status}[0]
#     run keyword if  "${Sku_Status.strip()}" == "1"  set global variable  ${chinese_build_status}  True
#     ...  ELSE  set global variable  ${chinese_build_status}  False
#     ${OS}=  Get OS Version Of Device
#     set global variable  ${DUT_OS}  ${OS}
#     Install LocalService App
#     run keyword if  ${chinese_build_status}  Change Language For Device  English  ${current_language}
#     run keyword if  "${Sku_Status.strip()}" == "1"  set global variable  ${chinese_build_status}  True
#     ...  ELSE  set global variable  ${chinese_build_status}  False
#
#     #************ Automation setup and N/W connection ***********************
#     Enable Setup for Automation  ${DUT1}
#     Create Test Bed PSK Profile And Install WLAN Apps
#
#     #************ BarcodeImageViewer Setup***********************
#     ${path}  setup_barcode_folder  VT327_Imgs
#     set global variable  ${BarcodeFolderpath}  ${path}
#
#     #*******Gets the DUT1 OS Version**************
#     Set Google Account Details
#     run keyword and ignore error  Unlock The Device Screen For All Security Locks
#     Setup Hardware Key Press For Device  ${DUT1}
#     set global variable  ${aim_mode_status}  True
#     set global variable  ${aim_timer_status}  True
#     ${status}  locate app  Camera
#     run keyword if  ${status}  set global variable  ${cam_status}  True
#     ...  ELSE  set global variable  ${cam_status}  False
#
#     #*******Staging Test Setup****************************
#     Install  ${EXTERNALFILES_DIRECTORY}\\Android\\APK\\StageNow\\Generic\\BarcodeStaging.apk
#     set security none
#     set_display_timeout_30mins  ${DUT1}
#     Battery Setup For Staging
#     run keyword and ignore error  Sdcard Setup Status
#     run keyword if  '${DI_EXEC_ENV}' == 'CLM'  run keywords
#     ...  DI Fetching And Downloading Builds From Smart Repo  ${lg_sr_main_url}  ${lg_search_sub_url}  ${lg_token_sub_url}  ${DUT_NAME}  A10  F  ${build_status}  ${device_platform}
#     ...  AND  Patching Validation Setup  ${LATEST_BASELINE_URL}  ${LATEST_BASELINE_PATCH_1_URL}  ${LATEST_BASELINE_PATCH_2_URL}
#     set global variable  ${DI_EXEC_ENV}  ${DI_EXEC_ENV}
#
#     #*************************SDCARD_NAME*********************
#     ${name}  run keyword if  '${DUT_NAME}' not in ['WS50']  run keywords
#     ...  Get SDCard Name for higher version
#     ...  AND  Set Global Variable  ${sdcard_name}  ${name}

# %%
len(extracted_content['Test_Cases'])
# Out:
# 8

# %%
import os 
from dotenv import load_dotenv
from langchain_openai import AzureChatOpenAI

def get_llm():
    load_dotenv(override=True)
    azure_deployment = os.environ.get('GPT4O_DEPLOYMENT_NAME')
    api_version = os.environ.get('GPT4O_API_VERSION')
    api_key = os.environ.get('GPT4O_API_KEY')
    azure_endpoint = os.environ.get('GPT4O_ENDPOINT')

    return AzureChatOpenAI(azure_deployment=azure_deployment,
openai_api_version=api_version,
openai_api_key=api_key,
azure_endpoint=azure_endpoint,
temperature=0)

def get_llm_response(prompt, llm=get_llm()):
    message = [
        {
            "role": "system",
            "content": "You are an expert at robot framework "
        },
        {
            "role": "user",
            "content": prompt
        }
    ]
    
    response = llm(messages=message)
    
    if hasattr(response, "content"):
        return response.content.strip()
    
    if isinstance(response, dict) and "choices" in response:
        if len(response["choices"]) > 0 and "message" in response["choices"][0]:
            return response["choices"][0]["message"]["content"].strip()
    
    return "No response content available."

# %%
prompt = ''' 
You are an expert in Robot Framework. I have the following components of a Robot Framework file stored in a dictionary:

For any reference about the indentation and the spacing you can refer this example robot file attached : {} . 


1. **Suite Setup**: The steps for the suite setup.
2. **Suite Teardown**: The steps for the suite teardown.
3. **Test Setup**: The steps for the test setup.
4. **Test Teardown**: The steps for the test teardown.
5. **Test Timeout**: The timeout value for each test case.
6. **Test Cases**: A dictionary where each key is a test case ID, and the value is the content of the test case.
7. **Libraries**: A list of libraries to import.
8. **Resources**: A list of resources to import.
9. **Variables**: The variables section of the file.
10. **Keywords**: The keywords section of the file.

The above mentioned components are attached here : {} .  Dont omit any test case , make sure all of them are present in the final robot file . 

Your task is to generate a complete Robot Framework file using these components alone , dont add your own stuff to any component. Follow these rules:

1. **Test Setup and Teardown**:
   - If a test case already has a `[Setup]` field, leave it unchanged. Otherwise create it and add the Test Setup steps to the `[Setup]` field.
   - If a test case already has a `[Teardown]` field, leave it unchanged. Otherwise create it and add the Test Teardown steps to the `[Teardown]` field. 

2. **Suite Setup and Teardown**:
   - Add the Suite Setup steps to the `[Setup]` field of the first test case, ensuring it appears before any existing setup.
   - Add the Suite Teardown steps to the `[Teardown]` field of the last test case, ensuring it appears after any existing teardown.
   - Make sure these are not added globally . 
   - These should be added only once each . 

3. **Test Timeout**:
   - Append the Test Timeout value to the end of every test case.
   - Dont add this globally . 
   - Dont add this to the last test case . 

4. **Formatting**:
   - Maintain proper indentation and formatting for Robot Framework files , use the example robot file for the reference of the same . 
   - USe AND to join any Teardowns or Setups . 

5. **Keywords**:
   - Add the keywords section at the end of the file . 

Output only the complete Robot Framework file as a single code block and nothing else , ensuring it adheres to the above rules and is ready to use. 
'''

# %%
with open("OS_Update3.0_Test.robot","r") as file : 
    example_robot = file.read()

response = get_llm_response(prompt.format(example_robot , extracted_content))

# %%
print(response)
# Out:
# ```robot
# *** Settings ***
# Library  Collections
# Library  ImageRecognitionLibrary
#
# Resource  ${EXECDIR}/Res/Android/AndroidGMS/AndroidGMS_Res.robot
# Resource  ${EXECDIR}/Res/Android/System/System_UIAutomator_Res.robot
# Resource  ${EXECDIR}/Res/Android/EMMTK/EMMTK_Keywords.robot
# Resource  ${EXECDIR}/Res/Android/DeviceImaging/DeviceImaging_UIAutomator_Res.robot
# Resource  ${EXECDIR}/Res/Common/NetworkTraffic/Ping_Res.robot
# Resource  ${EXECDIR}/Res/Android/Memory/AndroidMemory_UIAutomator_Res.robot
# Resource  ${EXECDIR}/Res/Android/RCR_Form/Parse_RCR_Form_Res.robot
# Resource  ${EXECDIR}/Res/Android/OOB/OOB_Settings_Res.robot
# Resource  ${EXECDIR}/Res/Android/Browser/Browser_UIAutomator_Res.robot
# Resource  ${EXECDIR}/Res/Android/EmdkScanner/Scanner_Injection_Common_Res.robot
# Resource  ${EXECDIR}/Res/Android/AndroidGMSLite/AndroidGMSLite_UIAutomator_Res.robot
# Resource  ${EXECDIR}/Res/Android/Android_Scan_Stress/Android_Scan_Stress_Res.robot
# Resource  ${EXECDIR}/Res/Android/Android/AEF/AEF_UIAutomator_Res.robot
#
# Variables  ${EXECDIR}/VariableFiles/Android/Android_OSUpdate/OS_Update3.0_Var.yaml
#
#
# *** Variables ***
# &{TOUCH_VIBRATION}  text=Haptic feedback for tap, keyboard, and more
# &{NOTIFICATION_SOUND}  text=Default notification sound
# &{DARK_THEME_LOCATOR}  text=Dark theme
#
# ${TESTSUITE_EXEC_TIMEOUT}  3000
# ${DI_EXEC_ENV}  NON-CLM
# ${A11_Previous_Build}  A10
# ${A13_Previous_Build}  A11
#
#
# *** Test Cases ***
#
# STTL-232540 - Pre Build Package --UPL- StageNow- Special packages + A11 Factory Reset package -internal location
#     [Setup]  Suite_Setup_OSUpdate
#     ...  Battery Setup For Staging
#     ...  AND  Install  ${EXTERNALFILES_DIRECTORY}\\Android\\APK\\StageNow\\Generic\\BarcodeStaging.apk
#     ...  AND  BuiltIn.Sleep  10
#     [Tags]  NON-CLM  CC610 (A11)  CC605 (A11)  ET51 (A11)  ET56 (A11)  EC50 (A11)  EC55 (A11)  L10A (A11)  MC22 (A11)  MC27 (A11)  MC33x (A11)  MC93 (A11)
#     ...  TC21 (A11)  TC26 (A11)  TC52 (A11)  TC52X (A11)  TC57 (A11)  TC57X (A11)  TC72 (A11)  TC77 (A11)  TC83 (A11)  TC53 (A11)  TC58 (A11)  WS50 (A11)
#     ${PLAT_FORM}  Get The Device Platform Name
#     Push File To Device  ${EXTERNALFILES_DIRECTORY}//${${PLAT_FORM}_Spl_Factory_Reset_Upl}  /sdcard
#     Push File To Device  ${EXTERNALFILES_DIRECTORY}//${${PLAT_FORM}_Automation_Enable_Pkg}  /sdcard
#     Initiate Stagging and Scan the Barcode  STTL_232540_${PLAT_FORM}.txt
#     ${is_rebooted} =  Check Boot Completed on DUT  600
#     run keyword unless  ${is_rebooted}  FAIL  DUT failed to Boot up after 600 seconds
#     Enable Setup For Automation  ${DUT1}
#     Disable Device Screen Auto-Rotation
#     ${status}  Execute ADB Shell Command On The Device  getprop ro.vendor.symbol.test.automation
#     Should Contain  ${status}  1
#     Create Test Bed PSK Profile And Install WLAN Apps
#     ${Test}  General_ADB_Res.Get Device WLAN Details
#     BuiltIn.Sleep  2s
#     Verify Ping From Host to Device  ${Test}[Device IP Address]
#     Browse Site  www.google.com
#     Scan Common Barcodes after Upgrade  STTL-232540  ${BC_DATA}
#     Delete Existing Albums in Gallery
#     Camera_UIAutomator_Res.Open Camera
#     run keyword if  '${DUT_NAME}' not in ['TC21', 'TC26', 'TC52X', 'TC57X', 'MC2200' 'MC2700', 'EC50', 'EC55', 'MC20', 'RZ_H270']  run keyword  set image capture mode
#     camera capture image  10
#     verify photo/video captured  10
#     Launch app  Calculator
#     Verify Device Screen Orientation for deviceimaging
#     FOR  ${index}  IN RANGE  0  5
#           AndroidGeneralUIAutomator.Reboot Device
#           Verify UUT in Homescreen
#     END
#     [Teardown]  run keywords
#     ...  run keyword if  '${DUT_NAME}' in ['EC30', 'VC8300', 'WT6300']  Set Screen Orientation  natural
#     ...  AND  run keyword if  '${DUT_NAME}' not in ['EC30', 'VC8300', 'WT6300']  Disable Device Screen Auto-Rotation
#     ...  AND  run keyword and ignore error  close imageview
#     ...  AND  Set Serial Number Of Device For All Libraries  ${DUT1}
#     ...  AND  run keyword and ignore error  Unlock The Device Screen For All Security Locks
#     ...  AND  run keyword and ignore error  Remove The Screen Lock Through Intent
#     [Timeout]  400 minutes
#
# STTL-230907 - Negative Test-AB streaming StageNOw-Osupdate3.0-Full OTA -Delta1-Suspend Resume
#     [Setup]  Test Build Pre_Condition SetUp  ${SA_A${DUT_OS}_BASELINE_LOCATION}  ${FULL_PACKAGE_UPDATE}  ${internal_path}  ${DUT1}
#     ...  Battery Setup For Staging
#     ...  AND  Install  ${EXTERNALFILES_DIRECTORY}\\Android\\APK\\StageNow\\Generic\\BarcodeStaging.apk
#     ...  AND  BuiltIn.Sleep  10
#     [Tags]  NON-CLM  TC53 (A11)  TC58 (A11)  TC15 (A11)  WS50 (A11)  TN28 (A11)
#     Create Test Bed PSK Profile And Install WLAN Apps
#     Upgrade OS Build With Full OTA Via AB Streaming  ${ABS_HTTP_NA_DELTA1}  ${DUT1}  ${SA_DELTA_1_A${DUT_OS}_LOCATION}  ${DELTA1_PACKAGE_NAME}
#     Suspend And Resume The Device
#     Functionality Test After Device Upgrade/Downgrade  STTL-230913  ${BC_DATA}
#     [Teardown]  Set Serial Number Of Device For All Libraries  ${DUT1}
#     ...  AND  run keyword and ignore error  Unlock The Device Screen For All Security Locks
#     ...  AND  run keyword and ignore error  Remove The Screen Lock Through Intent
#     [Timeout]  400 minutes
#
# STTL-230899 - Pre build -AB streaming Wifi -User Name and Password- Delta2 to FullOta of Delta 1-StaeNow-XML Barcode-downgrade
#     [Setup]  run keywords  Test Build Pre_Condition SetUp  ${SA_A${DUT_OS}_BASELINE_LOCATION}  ${FULL_PACKAGE_UPDATE}  ${internal_path}  ${DUT1}
#     ...  AND  Battery Setup For Staging
#     ...  AND  Install  ${EXTERNALFILES_DIRECTORY}\\Android\\APK\\StageNow\\Generic\\BarcodeStaging.apk
#     ...  AND  BuiltIn.Sleep  10
#     ...  AND  Upgrade OS Build With Diff OTA  ${SA_DELTA_1_A${DUT_OS}_LOCATION}  ${internal_path}  ${REVA_UPDATE}  ${DUT1}  ${DELTA1_PACKAGE_NAME}
#     ...  AND  Upgrade OS Build With Diff OTA  ${SA_DELTA_2_A${DUT_OS}_LOCATION}  ${internal_path}  ${REVA_UPDATE}  ${DUT1}  ${DELTA2_PACKAGE_NAME}
#     [Tags]  NON-CLM  TC53 (A11)  TC58 (A11)  TC15 (A11)  WS50 (A11)  TN28 (A11)
#     Create Test Bed PSK Profile And Install WLAN Apps
#     Upgrade OS Build With Full OTA Via AB Streaming  ${ABS_HTTP_NEXT_BA_DOWNGRADE}  ${DUT1}  ${SA_A13_NEXT_BASELINE_LOCATION}  ${FULL_PACKAGE_UPDATE}
#     Match all Version with RCR Form
#     Functionality Test After Device Upgrade/Downgrade  STTL-230913  ${BC_DATA}
#     [Teardown]  Set Serial Number Of Device For All Libraries  ${DUT1}
#     ...  AND  run keyword and ignore error  Unlock The Device Screen For All Security Locks
#     ...  AND  run keyword and ignore error  Remove The Screen Lock Through Intent
#     [Timeout]  400 minutes
#
# STTL-230895 - Pre build -AB streaming -HTTP-User Name and Password- Wifi -Full OTA -Delta1-StaeNow-XML Barcode
#     [Setup]  Test Build Pre_Condition SetUp  ${SA_A${DUT_OS}_BASELINE_LOCATION}  ${FULL_PACKAGE_UPDATE}  ${internal_path}  ${DUT1}
#     ...  Battery Setup For Staging
#     ...  AND  Install  ${EXTERNALFILES_DIRECTORY}\\Android\\APK\\StageNow\\Generic\\BarcodeStaging.apk
#     ...  AND  BuiltIn.Sleep  10
#     [Tags]  NON-CLM  TC53 (A11)  TC58 (A11)  TC15 (A11)  WS50 (A11)  TN28 (A11)
#     Create Test Bed PSK Profile And Install WLAN Apps
#     Upgrade OS Build With Full OTA Via AB Streaming  ${ABS_HTTP_NA_DELTA1}  ${DUT1}  ${SA_ABS_A${DUT_OS}_DELTA1}  ${DELTA1_PACKAGE_NAME}
#     Match all Version with RCR Form
#     Functionality Test After Device Upgrade/Downgrade  STTL-230913  ${BC_DATA}
#     [Teardown]  Set Serial Number Of Device For All Libraries  ${DUT1}
#     ...  AND  run keyword and ignore error  Unlock The Device Screen For All Security Locks
#     ...  AND  run keyword and ignore error  Remove The Screen Lock Through Intent
#     [Timeout]  400 minutes
#
# STTL-230890 - Pre build -Delta2 -to Delta3- OEMConfig -Test APK
#     [Setup]  run keywords  Test Build Pre_Condition SetUp  ${SA_A${DUT_OS}_BASELINE_LOCATION}  ${FULL_PACKAGE_UPDATE}  ${internal_path}  ${DUT1}
#     ...  AND  Battery Setup For Staging
#     ...  AND  Install  ${EXTERNALFILES_DIRECTORY}\\Android\\APK\\StageNow\\Generic\\BarcodeStaging.apk
#     ...  AND  BuiltIn.Sleep  10
#     ...  AND  Upgrade OS Build With Diff OTA  ${SA_DELTA_1_A${DUT_OS}_LOCATION}  ${internal_path}  ${REVA_UPDATE}  ${DUT1}  ${DELTA1_PACKAGE_NAME}
#     ...  AND  Upgrade OS Build With Diff OTA  ${SA_DELTA_2_A${DUT_OS}_LOCATION}  ${internal_path}  ${REVA_UPDATE}  ${DUT1}  ${DELTA2_PACKAGE_NAME}
#     ...  AND  Install OEMCONFIG Application
#     [Tags]  NON-CLM  TC53 (A11)  TC58 (A11)  TC15 (A11)  WS50 (A11)  TN28 (A11)
#     Enable Persistence Settings In The Device Before OSUpdate
#     DI Push ota packages to device  ${SA_DELTA_3_A${DUT_OS}_LOCATION}  ${DELTA3_PACKAGE_NAME}  ${internal_path}  ${DELTA3_PACKAGE_NAME}
#     run keyword if  ${OSVersion} >= 13  Set app restriction in TUT application  STTL_230890.json
#     ...  ELSE  Set app restriction in TUT application  STTL_230890.json
#     BuiltIn.Sleep  680
#     DeviceImaging_UIAutomator_Res.Device Boot up after Wipe/Factory/Enterprise Reset
#     BuiltIn.Sleep  5
#     AndroidGeneralUIAutomator.Reboot Device
#     Unlock The Device Screen For All Security Locks
#     run keyword and ignore error  TouchMgrCSP.Remove Device Owner
#     AEF_UIAutomator_Res.Remove Security PIN Lock Using Intent  ${LOGIN_PIN}
#     DI Validation Of Build Id With Manifest Xml  ${SA_DELTA_3_A${DUT_OS}_LOCATION}  ${DUT1}  ${DELTA3_PACKAGE_NAME}
#     Verify Persistence Settings In The Device After OSUpdate
#     [Teardown]  Set Serial Number Of Device For All Libraries  ${DUT1}
#     ...  AND  run keyword and ignore error  Unlock The Device Screen For All Security Locks
#     ...  AND  run keyword and ignore error  Remove The Screen Lock Through Intent
#     [Timeout]  400 minutes
#
# STTL-231747 - Pre build -AB Multiuser -Delta1-Delta2-StaeNow-XML Barcode
#     [Setup]  run keywords  Test Build Pre_Condition SetUp  ${SA_A${DUT_OS}_BASELINE_LOCATION}  ${FULL_PACKAGE_UPDATE}  ${internal_path}  ${DUT1}
#     ...  AND  Battery Setup For Staging
#     ...  AND  Install  ${EXTERNALFILES_DIRECTORY}\\Android\\APK\\StageNow\\Generic\\BarcodeStaging.apk
#     ...  AND  BuiltIn.Sleep  10
#     ...  AND  Upgrade OS Build With Diff OTA  ${SA_DELTA_1_A${DUT_OS}_LOCATION}  ${internal_path}  ${REVA_UPDATE}  ${DUT1}  ${DELTA1_PACKAGE_NAME}
#     [Tags]  NON-CLM  TC53 (A11)  TC58 (A11)  TC15 (A11)  WS50 (A11)  TN28 (A11)
#     Create Test Bed PSK Profile And Install WLAN Apps
#     Enable Multi User Feature in the Device
#     Create New User under Users and Accounts  U1
#     switch users  Owner
#     Enable Persistence Settings In The Device Before OSUpdate
#     Upgrade OS Build With Full OTA Via AB Streaming  ${ABS_HTTP_NA_DELTA2}  ${DUT1}  ${SA_DELTA_2_A${DUT_OS}_LOCATION}  ${DELTA2_PACKAGE_NAME}
#     Unlock The Device Screen For All Security Locks
#     AEF_UIAutomator_Res.Remove Security PIN Lock Using Intent  ${LOGIN_PIN}
#     Match all Version with RCR Form
#     AndroidGeneralUIAutomator.Reboot Device
#     Verify UUT in Homescreen
#     Switch Users  U1
#     Switch Users  Guest
#     switch users  Owner
#     Verify Persistence Settings In The Device After OSUpdate
#     run keyword if  '${persistence_settings}' == 'True' and '${verify_persistence_settings}' == 'False'  LOG  ${VERIFY_PERSISTENCE_FAILURES}
#     run keyword if  '${persistence_settings}' == 'False' and '${verify_persistence_settings}' == 'False'  LOG  ${PERSISTENCE_FAILURES} \n ${VERIFY_PERSISTENCE_FAILURES}
#     Functionality Test After Device Upgrade/Downgrade  STTL-230886  ${BC_DATA}
#     [Teardown]  Delete All Users through ADB from Owner
#
# STTL-230904 - AB streaming Downgrade from OSupdate3.0 Delta to Previous OS -Token
#     [Setup]  Run keywords  Test Build Pre_Condition SetUp  ${SA_A${DUT_OS}_BASELINE_LOCATION}  ${FULL_PACKAGE_UPDATE}  ${internal_path}  ${DUT1}
#     ...  AND  Battery Setup For Staging
#     ...  AND  Install  ${EXTERNALFILES_DIRECTORY}\\Android\\APK\\StageNow\\Generic\\BarcodeStaging.apk
#     ...  AND  BuiltIn.Sleep  10
#     ...  AND  Upgrade OS Build With Diff OTA  ${SA_DELTA_1_A${DUT_OS}_LOCATION}  ${internal_path}  ${REVA_UPDATE}  ${DUT1}  ${DELTA1_PACKAGE_NAME}
#     [Tags]  TC52 (A13)  MC33x (A13)  TC52x (A13)  TC72 (A13)  TC52ax (A13)  EC30 (A13)  MC22 (A13)  PS20J (A13)  TC77 (A13)  MC93 (A13)
#     ...  MC20 (A13)  TC21 (A13)  WT6300 (A13)  MC27 (A13)  TC57x (A13)  TC26 (A13)  RZ-H270 (A13)  MC33ax (A13)  EC50 (A13)  EC55 (A13)
#     ...  TC57 (A13)  TC83 (A13)
#     Create Test Bed PSK Profile And Install WLAN Apps
#     Delete Existing Albums in Gallery
#     Downgrade OS Build With Full OTA Via AB Streaming  ${ABS_HTTPS_BA_OS_DOWNGRADE_ZA}  ${DUT1}  ${SA_${A${DUT_OS}_Previous_Build}_BASELINE_LOCATION}  ${FULL_PACKAGE_UPDATE}  ${True}
#     [Teardown]  Unlock The Device Screen For All Security Locks
#
# STTL-244060 - AB streaming -Https -User Name and Password-Delta1 to Hotfox-StaeNow-XML Barcode
#     [Setup]  Run keywords  Test Build Pre_Condition SetUp  ${SA_A${DUT_OS}_BASELINE_LOCATION}  ${FULL_PACKAGE_UPDATE}  ${internal_path}  ${DUT1}
#     ...  AND  Battery Setup For Staging
#     ...  AND  Install  ${EXTERNALFILES_DIRECTORY}\\Android\\APK\\StageNow\\Generic\\BarcodeStaging.apk
#     ...  AND  BuiltIn.Sleep  10
#     ...  AND  Upgrade OS Build With Diff OTA  ${SA_DELTA_1_A${DUT_OS}_LOCATION}  ${internal_path}  ${REVA_UPDATE}  ${DUT1}  ${DELTA1_PACKAGE_NAME}
#     [Tags]  DI  CC610 (A11)  CC605 (A11)  ET51 (A11)  ET56 (A11)  EC50 (A11)  EC55 (A11)  L10A (A11)  MC22 (A11)  MC27 (A11)  MC33x (A11)  MC93 (A11)
#     ...  TC21 (A11)  TC26 (A11)  TC52 (A11)  TC52X (A11)  TC57 (A11)  TC57X (A11)  TC72 (A11)  TC77 (A11)  TC83 (A11)  TC15 (A11)  TC53 (A11)  TC58 (A11)
#     Enable Persistence Settings In The Device Before OSUpdate
#     Upgrade OS Build With Full OTA Via AB Streaming through HTTPS  ${ABS_HTTPS_BA_DELTA1_OR_HOTFIX}  ${DELTA1_PACKAGE_NAME}
#     Unlock The Device Screen For All Security Locks
#     AEF_UIAutomator_Res.Remove Security PIN Lock Using Intent  ${LOGIN_PIN}
#     Match all Version with RCR Form
#     Verify Persistence Settings In The Device After OSUpdate
#     Functionality Test After Device Upgrade/Downgrade  STTL-230913  ${BC_DATA}
#     [Teardown]  run keywords
#     ...  Perform Factory Reset
#     ...  AND  Enable Setup for Automation  ${DUT1}
#
#
# *** Keywords ***
#
# Suite_Setup_OSUpdate
#     [Documentation]  Get the device info
#     Set Serial Number Of Device For All Libraries  ${DUT1}
#     Universal Suite Setup  ${DUT1}
#     ${status}=  Get SDK Friendly Name Of Device
#     set global variable  ${OS_FLAVOUR}  ${status}
#     ${command}  set variable  shell getprop ro.config.bsp.gms
#     ${gms_status}=  execute adb command  ${command}
#     set global variable  ${dev_Gms_status}  ${gms_status[0]}
#     run keyword if  '${dev_Gms_status.strip()}' == 'true'  set global variable  ${build_status}  GMS
#     ...  ELSE  set global variable  ${build_status}  NGMS
#     ${platform}=  Get The Device Platform Name
#     ${command}  set variable  -s ${DUT1} shell getprop ro.config.device.china
#     @{Status}  execute adb command  ${command}
#     set global variable  ${Sku_Status}  ${Status}[0]
#     run keyword if  "${Sku_Status.strip()}" == "1"  set global variable  ${chinese_build_status}  True
#     ...  ELSE  set global variable  ${chinese_build_status}  False
#     ${OS}=  Get OS Version Of Device
#     set global variable  ${DUT_OS}  ${OS}
#     Install LocalService App
#     run keyword if  ${chinese_build_status}  Change Language For Device  English  ${current_language}
#     run keyword if  "${Sku_Status.strip()}" == "1"  set global variable  ${chinese_build_status}  True
#     ...  ELSE  set global variable  ${chinese_build_status}  False
#
#     #************ Automation setup and N/W connection ***********************
#     Enable Setup for Automation  ${DUT1}
#     Create Test Bed PSK Profile And Install WLAN Apps
#
#     #************ BarcodeImageViewer Setup***********************
#     ${path}  setup_barcode_folder  VT327_Imgs
#     set global variable  ${BarcodeFolderpath}  ${path}
#
#     #*******Gets the DUT1 OS Version**************
#     Set Google Account Details
#     run keyword and ignore error  Unlock The Device Screen For All Security Locks
#     Setup Hardware Key Press For Device  ${DUT1}
#     set global variable  ${aim_mode_status}  True
#     set global variable  ${aim_timer_status}  True
#     ${status}  locate app  Camera
#     run keyword if  ${status}  set global variable  ${cam_status}  True
#     ...  ELSE  set global variable  ${cam_status}  False
#
#     #*******Staging Test Setup****************************
#     Install  ${EXTERNALFILES_DIRECTORY}\\Android\\APK\\StageNow\\Generic\\BarcodeStaging.apk
#     set security none
#     set_display_timeout_30mins  ${DUT1}
#     Battery Setup For Staging
#     run keyword and ignore error  Sdcard Setup Status
#     run keyword if  '${DI_EXEC_ENV}' == 'CLM'  run keywords
#     ...  DI Fetching And Downloading Builds From Smart Repo  ${lg_sr_main_url}  ${lg_search_sub_url}  ${lg_token_sub_url}  ${DUT_NAME}  A10  F  ${build_status}  ${device_platform}
#     ...  AND  Patching Validation Setup  ${LATEST_BASELINE_URL}  ${LATEST_BASELINE_PATCH_1_URL}  ${LATEST_BASELINE_PATCH_2_URL}
#     set global variable  ${DI_EXEC_ENV}  ${DI_EXEC_ENV}
#
#     #*************************SDCARD_NAME*********************
#     ${name}  run keyword if  '${DUT_NAME}' not in ['WS50']  run keywords
#     ...  Get SDCard Name for higher version
#     ...  AND  Set Global Variable  ${sdcard_name}  ${name}
# ```

# %%
def remove_first_and_last_line(text):
    lines = text.strip().split("\n")
    if len(lines) > 2:
        return "\n".join(lines[1:-1])
    return "" 
response_filtered = remove_first_and_last_line(response)

# %%
with open("response.robot","w") as file : 
    file.write(response_filtered)
